# %%
import pandas as pd
df = pd.read_csv('Database FGVFlow - Página1.csv')
df.head()
# Out:
#    Q User  Q ID                                              Title  \
# 0  369535     1                                   What is anarchy?
# 1  395033     2  What is the difference between international a...
# 2  394341     3                                         SRA number
# 3  398940     4                  Get ready for microeconomics exam
# 4  312238     5              Getting in touch with Oliver Stuenkel
#
#                                       Questions Body  Q Score  Answer user  \
# 0  I did not really got what anarchy is. Does som...        5       371858
# 1  Answering the list 3 of IR Theory, I couldn't ...        4       333651
# 2                      What is the SRA phone number?        3       346008
# 3  I am having a microeconomics exam next week an...        6       396141
# 4  Hi, folks! I must talk w/ Oliver asap, but I c...        1       380425
#
#                                         Answers Body  A Score  \
# ...
